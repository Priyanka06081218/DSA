# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanka06081218/DSA/blob/main/Best_time_to_sell_and_Buy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def max_profit(prices):

    maxProfit = 0
    minPurchase = prices[0]

    for i in range(1, len(prices)):

        if prices[i] - minPurchase > maxProfit:
            maxProfit = prices[i] - minPurchase

        if prices[i] < minPurchase:
            minPurchase = prices[i]

    return maxProfit


prices = list(map(int, input("Enter prices: ").split()))

print("Maximum Profit:", max_profit(prices))
# Out:
# Enter prices: 3 9 6 7 1 22 18 30
# Maximum Profit: 29

# %% [markdown]
# ![IMG_4295.JPG](data:image/jpeg;base64,...)
