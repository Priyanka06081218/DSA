# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanka06081218/DSA/blob/main/Find_all_numbers_disappeared_in_an_array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums=[2,4,6,6,1,1,3,9]
res=[]
n=len(nums)
nums_set=set(nums)
for i in range(1, n+1):
  if i not in nums_set:
    res.append(i)
print(res)
# Out:
# [5, 7, 8]
