# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanka06081218/DSA/blob/main/Contains_Duplicate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = [1,2,2,1,3]

visited = set()
count = 0
found = False

for i in nums:
    if i in visited:
        count += 1
        print(True)
        found = True
        break

    visited.add(i)

if not found:
    print(False)
# Out:
# True

# %%
nums = [1,2,3,4]

visited = set()
count = 0
found = False

for i in nums:
    if i in visited:
        count += 1
        print(True)
        found = True
        break

    visited.add(i)

if not found:
    print(False)
# Out:
# False
