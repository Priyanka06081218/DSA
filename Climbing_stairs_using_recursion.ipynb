# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanka06081218/DSA/blob/main/Climbing_stairs_using_recursion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def climbStairs(n):
        if n == 1:
            return 1
        if n == 2:
            return 2
        return climbStairs(n-1) + climbStairs(n-2)


climbStairs(6)
# Out:
# 13
