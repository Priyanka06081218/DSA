# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanka06081218/DSA/blob/main/Find_Minimum_Operations_to_Make_All_Elements_Divisible_by_Three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums=[1,2,3,4]
count = 0
for num in nums:
  if num % 3 != 0:
    count += 1

print(count)
# Out:
# 3

# %%
nums=[3,6,9]
count = 0
for num in nums:
  if num % 3 != 0:
    count += 1

print(count)
# Out:
# 0
