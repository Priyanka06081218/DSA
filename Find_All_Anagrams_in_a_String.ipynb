# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanka06081218/DSA/blob/main/Find_All_Anagrams_in_a_String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:
    def findAnagrams(self, s, p):
        res = []
        p_count = {}
        window_count = {}

        # Count characters in p
        for char in p:
            p_count[char] = p_count.get(char, 0) + 1

        k = len(p)

        # Sliding window
        for i in range(len(s)):

            # Add the new character entering the window
            window_count[s[i]] = window_count.get(s[i], 0) + 1

            # Remove the character leaving the window
            if i >= k:
                left_char = s[i - k]
                window_count[left_char] -= 1

                if window_count[left_char] == 0:
                    del window_count[left_char]

            # Check whether current window is an anagram
            if window_count == p_count:
                res.append(i - k + 1)

        return res

solution = Solution()

s = "cbaebabacd"
p = "abc"

answer = solution.findAnagrams(s, p)

print(answer)
# Out:
# [0, 6]
