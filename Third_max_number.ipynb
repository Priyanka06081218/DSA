# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanka06081218/DSA/blob/main/Third_max_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = [2,33,43,1,2,2,90]

nums = list(set(nums))
nums.sort()

if len(nums) < 3:
    print(nums[-1])
else:
    print(nums[-3])
# Out:
# 33
