# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanka06081218/DSA/blob/main/Kth_largest_element_using_Quicksort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def findKthLargest(nums, k):

    def quicksort(left, right):

        if left >= right:
            return

        pivot = nums[left]

        i = left + 1
        j = right

        while i <= j:

            while i <= right and nums[i] < pivot:
                i += 1

            while j >= left and nums[j] > pivot:
                j -= 1

            if i < j:
                nums[i], nums[j] = nums[j], nums[i]
                i += 1
                j -= 1
            else:
                break

        nums[left], nums[j] = nums[j], nums[left]

        quicksort(left, j - 1)
        quicksort(j + 1, right)

    quicksort(0, len(nums) - 1)

    print("Sorted Array:", nums)
    print(f"{k}th Largest Element:", nums[len(nums) - k])


nums = [3,2,1,12,32,56,23]
k = 2

findKthLargest(nums, k)
# Out:
# Sorted Array: [1, 2, 3, 12, 23, 32, 56]
# 2th Largest Element: 32
